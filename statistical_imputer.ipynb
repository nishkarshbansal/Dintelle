# %% [markdown]
# <a href="https://colab.research.google.com/github/nishkarshbansal/Dintelle/blob/main/statistical_imputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
z = 'business-financial-data-september-2022-quarter.csv'
df = pd.read_csv(z)
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6190     BDCQ.SF8RSCA  2021.09     382.195        NaN      F  Dollars
# 6191     BDCQ.SF8RSCA  2021.12     397.184        NaN      F  Dollars
# 6192     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
df.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value           475
# Suppressed          6180
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      6195
# dtype: int64

# %%
#if we want to use the same algo for whole dataframe

# mean_imputer = SimpleImputer(strategy='mean')
# result_mean_imputer = mean_imputer.fit_transform0(df)
# pd.DataFrame(result_mean_imputer, columns=list(z))

#By column to column
mean_imputer = SimpleImputer(strategy='mean')
df.Data_value = mean_imputer.fit_transform(df['Data_value'].values.reshape(-1,1))[:,0]
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6190     BDCQ.SF8RSCA  2021.09     382.195        NaN      F  Dollars
# 6191     BDCQ.SF8RSCA  2021.12     397.184        NaN      F  Dollars
# 6192     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
df.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value             0
# Suppressed          6180
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      6195
# dtype: int64

# %%
df
# Out:
#             Quarter    Q1
# 2               NaN   NaN
# 4        1E0166 STL  2039
# 5        1E0357 STL  1879
# 6        1E0170 STL   398
# 7           (blank)   189
# ..              ...   ...
# 64       1E0361 STL     1
# 65  1E0551 STL PIPE     1
# 66       1E0832 STL     1
# 67       1E0911 SST     1
# 68      Grand Total  4411
#
# [66 rows x 2 columns]

# %%
missing_col = ['Data_value']
#Technique 1: Using mean to impute the missing values
for i in missing_col:
 df.loc[df.loc[:,i].isnull(),i]=df.loc[:,i].mean()

# %%
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6190     BDCQ.SF8RSCA  2021.09     382.195        NaN      F  Dollars
# 6191     BDCQ.SF8RSCA  2021.12     397.184        NaN      F  Dollars
# 6192     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
df.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value             0
# Suppressed          6180
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      6195
# dtype: int64

# %% [markdown]
# # New section
